# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzeelAbbas/DL_Files/blob/main/GPT_2_on_Squad_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Load SQuAD dataset**

# %%
# ! pip install transformers datasets evaluate
from datasets import load_dataset

squad = load_dataset("squad", split="train[:600]")

# %%
# Split the dataset’s train split into a train and test set with the train_test_split method

squad = squad.train_test_split(test_size=0.2)

squad["train"][2]
# Out:
# {'id': '5733cbdad058e614000b628f',
#  'title': 'University_of_Notre_Dame',
#  'context': 'The "Notre Dame Victory March" is the fight song for the University of Notre Dame. It was written by two brothers who were Notre Dame graduates. The Rev. Michael J. Shea, a 1904 graduate, wrote the music, and his brother, John F. Shea, who earned degrees in 1906 and 1908, wrote the original lyrics. The lyrics were revised in the 1920s; it first appeared under the copyright of the University of Notre Dame in 1928. The chorus is, "Cheer cheer for old Notre Dame, wake up the echos cheering her name. Send a volley cheer on high, shake down the thunder from the sky! What though the odds be great or small, old Notre Dame will win over all. While her loyal sons are marching, onward to victory!"',
#  'question': 'Who is responsible for writing the music for "Notre Dame Victory March?"',
#  'answers': {'text': ['Rev. Michael J. Shea'], 'answer_start': [149]}}

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
import torch

tokenizer = AutoTokenizer.from_pretrained("gpt2")

model = AutoModelForQuestionAnswering.from_pretrained("gpt2")

# Set the padding token to '[PAD]'
tokenizer.pad_token = "[PAD]"
# Out:
# Some weights of GPT2ForQuestionAnswering were not initialized from the model checkpoint at gpt2 and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    # Add a print statement here
    print(f"Total examples: {len(offset_mapping)}")

    for i, offset in enumerate(offset_mapping):
        # Add another print statement here
        print(f"Processing example {i + 1}/{len(offset_mapping)}")
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        idx = 0
        while idx < len(sequence_ids) and sequence_ids[idx] != 1:
            idx += 1
        context_start = idx

        while idx < len(sequence_ids) and sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label it (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
tokenized_squad = squad.map(preprocess_function, batched=True, remove_columns=squad["train"].column_names)
# Out:
# Map:   0%|          | 0/480 [00:00<?, ? examples/s]
# Total examples: 480
# Processing example 1/480
# Processing example 2/480
# Processing example 3/480
# Processing example 4/480
# Processing example 5/480
# Processing example 6/480
# Processing example 7/480
# Processing example 8/480
# Processing example 9/480
# Processing example 10/480
# Processing example 11/480
# Processing example 12/480
# Processing example 13/480
# Processing example 14/480
# Processing example 15/480
# Processing example 16/480
# Processing example 17/480
# Processing example 18/480
# Processing example 19/480
# Processing example 20/480
# Processing example 21/480
# Processing example 22/480
# Processing example 23/480
# Processing example 24/480
# Processing example 25/480
# Processing example 26/480
# Processing example 27/480
# Processing example 28/480
# Processing example 29/480
# Processing example 30/480
# Processing example 31/480
# Processing example 32/480
# Processing example 33/480
# Processing example 34/480
# Processing example 35/480
# Processing example 36/480
# Processing example 37/480
# Processing example 38/480
# Processing example 39/480
# Processing example 40/480
# Processing example 41/480
# Processing example 42/480
# Processing example 43/480
# Processing example 44/480
# Processing example 45/480
# Processing example 46/480
# Processing example 47/480
# Processing example 48/480
# Processing example 49/480
# Processing example 50/480
# Processing example 51/480
# Processing example 52/480
# Processing example 53/480
# Processing example 54/480
# Processing example 55/480
# Processing example 56/480
# Processing example 57/480
# Processing example 58/480
# Processing example 59/480
# Processing example 60/480
# Processing example 61/480
# Processing example 62/480
# Processing example 63/480
# Processing example 64/480
# Processing example 65/480
# Processing example 66/480
# Processing example 67/480
# Processing example 68/480
# Processing example 69/480
# Processing example 70/480
# Processing example 71/480
# Processing example 72/480
# Processing example 73/480
# Processing example 74/480
# Processing example 75/480
# Processing example 76/480
# Processing example 77/480
# Processing example 78/480
# Processing example 79/480
# Processing example 80/480
# Processing example 81/480
# Processing example 82/480
# Processing example 83/480
# Processing example 84/480
# Processing example 85/480
# Processing example 86/480
# Processing example 87/480
# Processing example 88/480
# Processing example 89/480
# Processing example 90/480
# Processing example 91/480
# Processing example 92/480
# Processing example 93/480
# Processing example 94/480
# Processing example 95/480
# Processing example 96/480
# Processing example 97/480
# Processing example 98/480
# Processing example 99/480
# Processing example 100/480
# Processing example 101/480
# Processing example 102/480
# Processing example 103/480
# Processing example 104/480
# Processing example 105/480
# Processing example 106/480
# Processing example 107/480
# Processing example 108/480
# Processing example 109/480
# Processing example 110/480
# Processing example 111/480
# Processing example 112/480
# Processing example 113/480
# Processing example 114/480
# Processing example 115/480
# Processing example 116/480
# Processing example 117/480
# Processing example 118/480
# Processing example 119/480
# Processing example 120/480
# Processing example 121/480
# Processing example 122/480
# Processing example 123/480
# Processing example 124/480
# Processing example 125/480
# Processing example 126/480
# Processing example 127/480
# Processing example 128/480
# Processing example 129/480
# Processing example 130/480
# Processing example 131/480
# Processing example 132/480
# Processing example 133/480
# Processing example 134/480
# Processing example 135/480
# Processing example 136/480
# Processing example 137/480
# Processing example 138/480
# Processing example 139/480
# Processing example 140/480
# Processing example 141/480
# Processing example 142/480
# Processing example 143/480
# Processing example 144/480
# Processing example 145/480
# Processing example 146/480
# Processing example 147/480
# Processing example 148/480
# Processing example 149/480
# Processing example 150/480
# Processing example 151/480
# Processing example 152/480
# Processing example 153/480
# Processing example 154/480
# Processing example 155/480
# Processing example 156/480
# Processing example 157/480
# Processing example 158/480
# Processing example 159/480
# Processing example 160/480
# Processing example 161/480
# Processing example 162/480
# Processing example 163/480
# Processing example 164/480
# Processing example 165/480
# Processing example 166/480
# Processing example 167/480
# Processing example 168/480
# Processing example 169/480
# Processing example 170/480
# Processing example 171/480
# Processing example 172/480
# Processing example 173/480
# Processing example 174/480
# Processing example 175/480
# Processing example 176/480
# Processing example 177/480
# Processing example 178/480
# Processing example 179/480
# Processing example 180/480
# Processing example 181/480
# Processing example 182/480
# Processing example 183/480
# Processing example 184/480
# Processing example 185/480
# Processing example 186/480
# Processing example 187/480
# Processing example 188/480
# Processing example 189/480
# Processing example 190/480
# Processing example 191/480
# Processing example 192/480
# Processing example 193/480
# Processing example 194/480
# Processing example 195/480
# Processing example 196/480
# Processing example 197/480
# Processing example 198/480
# Processing example 199/480
# Processing example 200/480
# Processing example 201/480
# Processing example 202/480
# Processing example 203/480
# Processing example 204/480
# Processing example 205/480
# Processing example 206/480
# Processing example 207/480
# Processing example 208/480
# Processing example 209/480
# Processing example 210/480
# Processing example 211/480
# Processing example 212/480
# Processing example 213/480
# Processing example 214/480
# Processing example 215/480
# Processing example 216/480
# Processing example 217/480
# Processing example 218/480
# Processing example 219/480
# Processing example 220/480
# Processing example 221/480
# Processing example 222/480
# Processing example 223/480
# Processing example 224/480
# Processing example 225/480
# Processing example 226/480
# Processing example 227/480
# Processing example 228/480
# Processing example 229/480
# Processing example 230/480
# Processing example 231/480
# Processing example 232/480
# Processing example 233/480
# Processing example 234/480
# Processing example 235/480
# Processing example 236/480
# Processing example 237/480
# Processing example 238/480
# Processing example 239/480
# Processing example 240/480
# Processing example 241/480
# Processing example 242/480
# Processing example 243/480
# Processing example 244/480
# Processing example 245/480
# Processing example 246/480
# Processing example 247/480
# Processing example 248/480
# Processing example 249/480
# Processing example 250/480
# Processing example 251/480
# Processing example 252/480
# Processing example 253/480
# Processing example 254/480
# Processing example 255/480
# Processing example 256/480
# Processing example 257/480
# Processing example 258/480
# Processing example 259/480
# Processing example 260/480
# Processing example 261/480
# Processing example 262/480
# Processing example 263/480
# Processing example 264/480
# Processing example 265/480
# Processing example 266/480
# Processing example 267/480
# Processing example 268/480
# Processing example 269/480
# Processing example 270/480
# Processing example 271/480
# Processing example 272/480
# Processing example 273/480
# Processing example 274/480
# Processing example 275/480
# Processing example 276/480
# Processing example 277/480
# Processing example 278/480
# Processing example 279/480
# Processing example 280/480
# Processing example 281/480
# Processing example 282/480
# Processing example 283/480
# Processing example 284/480
# Processing example 285/480
# Processing example 286/480
# Processing example 287/480
# Processing example 288/480
# Processing example 289/480
# Processing example 290/480
# Processing example 291/480
# Processing example 292/480
# Processing example 293/480
# Processing example 294/480
# Processing example 295/480
# Processing example 296/480
# Processing example 297/480
# Processing example 298/480
# Processing example 299/480
# Processing example 300/480
# Processing example 301/480
# Processing example 302/480
# Processing example 303/480
# Processing example 304/480
# Processing example 305/480
# Processing example 306/480
# Processing example 307/480
# Processing example 308/480
# Processing example 309/480
# Processing example 310/480
# Processing example 311/480
# Processing example 312/480
# Processing example 313/480
# Processing example 314/480
# Processing example 315/480
# Processing example 316/480
# Processing example 317/480
# Processing example 318/480
# Processing example 319/480
# Processing example 320/480
# Processing example 321/480
# Processing example 322/480
# Processing example 323/480
# Processing example 324/480
# Processing example 325/480
# Processing example 326/480
# Processing example 327/480
# Processing example 328/480
# Processing example 329/480
# Processing example 330/480
# Processing example 331/480
# Processing example 332/480
# Processing example 333/480
# Processing example 334/480
# Processing example 335/480
# Processing example 336/480
# Processing example 337/480
# Processing example 338/480
# Processing example 339/480
# Processing example 340/480
# Processing example 341/480
# Processing example 342/480
# Processing example 343/480
# Processing example 344/480
# Processing example 345/480
# Processing example 346/480
# Processing example 347/480
# Processing example 348/480
# Processing example 349/480
# Processing example 350/480
# Processing example 351/480
# Processing example 352/480
# Processing example 353/480
# Processing example 354/480
# Processing example 355/480
# Processing example 356/480
# Processing example 357/480
# Processing example 358/480
# Processing example 359/480
# Processing example 360/480
# Processing example 361/480
# Processing example 362/480
# Processing example 363/480
# Processing example 364/480
# Processing example 365/480
# Processing example 366/480
# Processing example 367/480
# Processing example 368/480
# Processing example 369/480
# Processing example 370/480
# Processing example 371/480
# Processing example 372/480
# Processing example 373/480
# Processing example 374/480
# Processing example 375/480
# Processing example 376/480
# Processing example 377/480
# Processing example 378/480
# Processing example 379/480
# Processing example 380/480
# Processing example 381/480
# Processing example 382/480
# Processing example 383/480
# Processing example 384/480
# Processing example 385/480
# Processing example 386/480
# Processing example 387/480
# Processing example 388/480
# Processing example 389/480
# Processing example 390/480
# Processing example 391/480
# Processing example 392/480
# Processing example 393/480
# Processing example 394/480
# Processing example 395/480
# Processing example 396/480
# Processing example 397/480
# Processing example 398/480
# Processing example 399/480
# Processing example 400/480
# Processing example 401/480
# Processing example 402/480
# Processing example 403/480
# Processing example 404/480
# Processing example 405/480
# Processing example 406/480
# Processing example 407/480
# Processing example 408/480
# Processing example 409/480
# Processing example 410/480
# Processing example 411/480
# Processing example 412/480
# Processing example 413/480
# Processing example 414/480
# Processing example 415/480
# Processing example 416/480
# Processing example 417/480
# Processing example 418/480
# Processing example 419/480
# Processing example 420/480
# Processing example 421/480
# Processing example 422/480
# Processing example 423/480
# Processing example 424/480
# Processing example 425/480
# Processing example 426/480
# Processing example 427/480
# Processing example 428/480
# Processing example 429/480
# Processing example 430/480
# Processing example 431/480
# Processing example 432/480
# Processing example 433/480
# Processing example 434/480
# Processing example 435/480
# Processing example 436/480
# Processing example 437/480
# Processing example 438/480
# Processing example 439/480
# Processing example 440/480
# Processing example 441/480
# Processing example 442/480
# Processing example 443/480
# Processing example 444/480
# Processing example 445/480
# Processing example 446/480
# Processing example 447/480
# Processing example 448/480
# Processing example 449/480
# Processing example 450/480
# Processing example 451/480
# Processing example 452/480
# Processing example 453/480
# Processing example 454/480
# Processing example 455/480
# Processing example 456/480
# Processing example 457/480
# Processing example 458/480
# Processing example 459/480
# Processing example 460/480
# Processing example 461/480
# Processing example 462/480
# Processing example 463/480
# Processing example 464/480
# Processing example 465/480
# Processing example 466/480
# Processing example 467/480
# Processing example 468/480
# Processing example 469/480
# Processing example 470/480
# Processing example 471/480
# Processing example 472/480
# Processing example 473/480
# Processing example 474/480
# Processing example 475/480
# Processing example 476/480
# Processing example 477/480
# Processing example 478/480
# Processing example 479/480
# Processing example 480/480
# Map:   0%|          | 0/120 [00:00<?, ? examples/s]
# Total examples: 120
# Processing example 1/120
# Processing example 2/120
# Processing example 3/120
# Processing example 4/120
# Processing example 5/120
# Processing example 6/120
# Processing example 7/120
# Processing example 8/120
# Processing example 9/120
# Processing example 10/120
# Processing example 11/120
# Processing example 12/120
# Processing example 13/120
# Processing example 14/120
# Processing example 15/120
# Processing example 16/120
# Processing example 17/120
# Processing example 18/120
# Processing example 19/120
# Processing example 20/120
# Processing example 21/120
# Processing example 22/120
# Processing example 23/120
# Processing example 24/120
# Processing example 25/120
# Processing example 26/120
# Processing example 27/120
# Processing example 28/120
# Processing example 29/120
# Processing example 30/120
# Processing example 31/120
# Processing example 32/120
# Processing example 33/120
# Processing example 34/120
# Processing example 35/120
# Processing example 36/120
# Processing example 37/120
# Processing example 38/120
# Processing example 39/120
# Processing example 40/120
# Processing example 41/120
# Processing example 42/120
# Processing example 43/120
# Processing example 44/120
# Processing example 45/120
# Processing example 46/120
# Processing example 47/120
# Processing example 48/120
# Processing example 49/120
# Processing example 50/120
# Processing example 51/120
# Processing example 52/120
# Processing example 53/120
# Processing example 54/120
# Processing example 55/120
# Processing example 56/120
# Processing example 57/120
# Processing example 58/120
# Processing example 59/120
# Processing example 60/120
# Processing example 61/120
# Processing example 62/120
# Processing example 63/120
# Processing example 64/120
# Processing example 65/120
# Processing example 66/120
# Processing example 67/120
# Processing example 68/120
# Processing example 69/120
# Processing example 70/120
# Processing example 71/120
# Processing example 72/120
# Processing example 73/120
# Processing example 74/120
# Processing example 75/120
# Processing example 76/120
# Processing example 77/120
# Processing example 78/120
# Processing example 79/120
# Processing example 80/120
# Processing example 81/120
# Processing example 82/120
# Processing example 83/120
# Processing example 84/120
# Processing example 85/120
# Processing example 86/120
# Processing example 87/120
# Processing example 88/120
# Processing example 89/120
# Processing example 90/120
# Processing example 91/120
# Processing example 92/120
# Processing example 93/120
# Processing example 94/120
# Processing example 95/120
# Processing example 96/120
# Processing example 97/120
# Processing example 98/120
# Processing example 99/120
# Processing example 100/120
# Processing example 101/120
# Processing example 102/120
# Processing example 103/120
# Processing example 104/120
# Processing example 105/120
# Processing example 106/120
# Processing example 107/120
# Processing example 108/120
# Processing example 109/120
# Processing example 110/120
# Processing example 111/120
# Processing example 112/120
# Processing example 113/120
# Processing example 114/120
# Processing example 115/120
# Processing example 116/120
# Processing example 117/120
# Processing example 118/120
# Processing example 119/120
# Processing example 120/120

# %%
import os

os.environ["HF_HOME"] = "/root/.huggingface"
os.environ["HF_HOME"] += "/token"
os.environ["HF_HOME"] = os.path.join(os.environ["HF_HOME"], "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")

# %%
from transformers import DefaultDataCollator

data_collator = DefaultDataCollator()

# %% [markdown]
# # **Model Training**
#
# 1. Define training hyperparameters in TrainingArguments. The only required parameter is output_dir which specifies where to save your model. We’ll push this model to the Hub by setting push_to_hub=True (we need to be signed in to Hugging Face to upload your model).
# 2. Pass the training arguments to Trainer along with the model, dataset, tokenizer, and data collator.
# 3. Call train() to finetune model.

# %%
# !pip install accelerate -U

training_args = TrainingArguments(
    output_dir="/content",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_steps=20,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_squad["train"],
    eval_dataset=tokenized_squad["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='90' max='90' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [90/90 01:57, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.009900</td>
#       <td>3.843750</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.849000</td>
#       <td>3.654203</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.785500</td>
#       <td>3.558265</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=90, training_loss=2.9058094024658203, metrics={'train_runtime': 118.8954, 'train_samples_per_second': 12.111, 'train_steps_per_second': 0.757, 'total_flos': 282200497274880.0, 'train_loss': 2.9058094024658203, 'epoch': 3.0})

# %% [markdown]
# # **Evaluate Model**

# %%
# Define your data collator
data_collator = DefaultDataCollator()

# Define evaluation arguments
evaluation_args = TrainingArguments(
    per_device_eval_batch_size=16,  # Adjust batch size for evaluation if needed
    output_dir="./evaluation_results",  # Specify an output directory for evaluation results
)

# Create a Trainer for evaluation
eval_trainer = Trainer(
    model=model,
    args=evaluation_args,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Evaluate the model on the test dataset
eval_results = eval_trainer.evaluate(tokenized_squad["test"])

# Print the evaluation results
print(eval_results)
# Out:
#     <div>
#
#       <progress value='8' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8/8 00:02]
#     </div>
# {'eval_loss': 3.55826473236084, 'eval_runtime': 2.9999, 'eval_samples_per_second': 40.001, 'eval_steps_per_second': 2.667}

# %% [markdown]
# # **Predict Answer**

# %%
context = 'The "Notre Dame Victory March" is the fight song for the University of Notre Dame. It was written by two brothers who were Notre Dame graduates. The Rev. Michael J. Shea, a 1904 graduate, wrote the music, and his brother, John F. Shea, who earned degrees in 1906 and 1908, wrote the original lyrics. The lyrics were revised in the 1920s; it first appeared under the copyright of the University of Notre Dame in 1928. The chorus is, "Cheer cheer for old Notre Dame, wake up the echos cheering her name. Send a volley cheer on high, shake down the thunder from the sky! What though the odds be great or small, old Notre Dame will win over all. While her loyal sons are marching, onward to victory!'
question = "Who is responsible for writing the music for 'Notre Dame Victory March?'"

# Tokenize the question and context
inputs = tokenizer(question, context, return_tensors="pt")

# Move the inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate predictions
with torch.no_grad():
    outputs = model(**inputs)
    start_logits = outputs.start_logits
    end_logits = outputs.end_logits

# Find the answer span
start_idx = torch.argmax(start_logits)
end_idx = torch.argmax(end_logits)

# Convert indices to Python integers
start_idx = start_idx.item()
end_idx = end_idx.item()

# Tokenize the context and extract the answer span
context_tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
answer_tokens = context_tokens[start_idx:end_idx + 1]
answer = tokenizer.convert_tokens_to_string(answer_tokens)

print(answer)
# Out:
#  Rev. Michael J. Shea, a 1904 graduate, wrote the music, and his brother, John F. Shea
